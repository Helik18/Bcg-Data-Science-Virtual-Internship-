# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # LOAD DATA

# %%
client = pd.read_csv("/content/client_data (1) (1).csv")
price = pd.read_csv("price_data (1) (1).csv")

# %%
client.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
date=["date_activ", "date_end", "date_modif_prod", "date_renewal"]

# %%
for i in date:
  client[i] = pd.to_datetime(client[i])

# %%
price["price_date"] = pd.to_datetime(price["price_date"])

# %%
client.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  \
# count  1.460600e+04  1.460600e+04     14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752
# min    0.000000e+00  0.000000e+00         0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000
# 50%    1.411550e+04  0.000000e+00       792.500000
# 75%    4.076375e+04  0.000000e+00      3383.000000
# max    6.207104e+06  4.154590e+06    771203.000000
# std    5.734653e+05  1.629731e+05     64364.196422
#
#                           date_activ                       date_end  \
# count                          14606                          14606
# mean   2011-01-28 07:54:18.879912448  2016-07-27 20:48:26.422018560
# min              2003-05-09 00:00:00            2016-01-28 00:00:00
# 25%              2010-01-15 00:00:00            2016-04-27 06:00:00
# 50%              2011-03-04 00:00:00            2016-08-01 00:00:00
# 75%              2012-04-19 00:00:00            2016-10-31 00:00:00
# ...

# %%
price.describe()
# Out:
#                           price_date  price_off_peak_var  price_peak_var  \
# count                         193002       193002.000000   193002.000000
# mean   2015-06-16 12:50:49.933161216            0.141027        0.054630
# min              2015-01-01 00:00:00            0.000000        0.000000
# 25%              2015-04-01 00:00:00            0.125976        0.000000
# 50%              2015-07-01 00:00:00            0.146033        0.085483
# 75%              2015-10-01 00:00:00            0.151635        0.101673
# max              2015-12-01 00:00:00            0.280700        0.229788
# std                              NaN            0.025032        0.049924
#
#        price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# count       193002.000000       193002.000000   193002.000000
# mean             0.030496           43.334477       10.622875
# min              0.000000            0.000000        0.000000
# ...

# %%
client.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
churn=client[['id','churn']]
churn.columns=['Companies','churn']
churn_total=churn.groupby(churn['churn']).count()
churn_percentage=churn_total/churn_total.sum()*100
churn_percentage
# Out:
#        Companies
# churn
# 0      90.284814
# 1       9.715186

# %%
# creating best distribution possible for all columns for showing customer churn due to price elasticity

import matplotlib.pyplot as plt
import numpy as np
# Distribution of numerical columns
numerical_cols = client.select_dtypes(include=np.number).columns.tolist()
client[numerical_cols].hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

numerical_cols = price.select_dtypes(include=np.number).columns.tolist()
price[numerical_cols].hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# Distribution of categorical columns
categorical_cols = client.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=client, x=col, palette='viridis')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

categorical_cols = price.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=price, x=col, palette='viridis')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Distribution of datetime columns
datetime_cols = client.select_dtypes(include='datetime64[ns]').columns.tolist()
for col in datetime_cols:
    plt.figure(figsize=(12, 6))
    client[col].dt.year.value_counts().sort_index().plot(kind='bar')
    plt.title(f'Distribution of {col} by Year')
    plt.xlabel('Year')
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(12, 6))
price['price_date'].dt.year.value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of price_date by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
